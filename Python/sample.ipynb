# %% [markdown]
# # This is My first script
# Hi Python is a very simple language

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array(range(10))
b=a*3+7
print(b)
plt.plot(a,b)
# Out:
# [ 7 10 13 16 19 22 25 28 31 34]
